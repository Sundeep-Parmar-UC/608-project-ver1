# %% [markdown]
# <h1>Data Ingestion and Training By: G5-Rita Group</h1><i>notebook edition</i><br>
# 1). Obtain<br>
# 2). Decompress<br>
# 3). Parse<br>
# <li>
# <ol>A) Load Game</ol>
# <ol>B) Parse Move</ol>
# <ol>C) Load Move</ol>
# </li>
# 4). Cleanup

# %%
#Define connection to MYSQL Server
ConnectString = "mysql -h database-1.cfvrvxxcdsku.ca-west-1.rds.amazonaws.com -P 3306 -u admin -p --ssl-mode=VERIFY_IDENTITY --ssl-ca=./global-bundle.pem"

host=ConnectString[9:60]
user='admin'
password='Data608-Project'
database='CHESSBOT'

# %%
#Define file to load into Database

#Provide two-digit month   (01 -> 12)
File_month = "03"

#Provide four-digit year  (2026  <- 2013 )
File_year = "2018"

# %%
### Check if file was loaded already  else load stub and obtain id for latter
import mysql.connector
import files as fs
import time
print(time.ctime())
# Out:
# Sun Mar 29 16:03:03 2026

# %% [markdown]
# #### Define file to load into Database
#
# #Provide two-digit month   (01 -> 12)
# File_month = "12"
#
# #Provide four-digit year  (2026  <- 2013 )
# File_year = "2013"

# %%
####   OBTAIN   the file using bash commands

import subprocess
import os
print(time.ctime()) 

# Define your variables
EBSPath = "/data"
CompressedFileName = f"lichess_db_standard_rated_{File_year}-{File_month}.pgn.zst"
CompressedCompletePath = f"https://database.lichess.org/standard/{CompressedFileName}"

DownloadedCompressedFile = "/data/lichess_db_standard_rated_" + File_year + "-" + File_month + ".pgn.zst"
file_size = os.path.getsize(DownloadedCompressedFile)
print(f"Size: {file_size} bytes")

print(time.ctime())
# Out:
# Sun Mar 29 16:03:03 2026
# Size: 6567583338 bytes
# Sun Mar 29 16:03:03 2026

# %%
####   DECOMPRESS the file using bash commands
import zstandard as zstd
UnCompressedCompletePath = DownloadedCompressedFile[:-4]
print(time.ctime()) 

    
print(f"Decompression finished: {UnCompressedCompletePath}")
print(time.ctime())
# Out:
# Sun Mar 29 16:03:03 2026
# Decompression finished: /data/lichess_db_standard_rated_2018-03.pgn
# Sun Mar 29 16:03:03 2026

# %%
### PARSE the uncompressed file
print(time.ctime()) 
import parse as pa
metric = []
successbit = False

metric,successbit = pa.Parse(UnCompressedCompletePath,"cursor")
print("Total Events Ingested: ",metric[0])
print("Total Events Considered: ",metric[1])
print("Log results: ",metric[2])
print(time.ctime())
# Out:
# Sun Mar 29 16:03:03 2026
# 1. e3 e5 2. d4 f6 3. f4 d6 4. c3 Be6 5. Be2 c6 6. Nf3 d5 7. fxe5 fxe5 8. Nxe5 Bd6 9. Nd3 Nd7 10. Qb3 Ne7 11. c4 O-O 12. cxd5 cxd5 13. Qb6 Nxb6 14. h3 Nec8 15. g4 Qh4+ 16. Nf2 Qd8 17. e4 dxe4 18. Nxe4 Bc4 19. Bf3 Nd5 20. Rf1 Bxf1 21. Kxf1 Rxf3+ 22. Ke2 Rxh3 23. Bg5 Qa5 24. Nf2 Rh2 25. a3 Ncb6 26. b4 Qa4 27. Kd3 Rxf2 28. Nc3 Qc2# 0-1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       4 metric = []
#       5 successbit = False
# ----> 7 metric,successbit = pa.Parse(UnCompressedCompletePath,"cursor")
#       8 print("Total Events Ingested: ",metric[0])
#       9 print("Total Events Considered: ",metric[1])
#
# File ~/venv/bin/parse.py:53, in Parse(uncompressFilePath, SQLconnect)
#      51             elif line.startswith('1. '): #Found Moves info
#      52                 MovesData = line.strip() # Use the entire line for the Moves column
# ---> 53                 if MoveValidation(MovesData):
#      54                     MoveLineGathered = True  #found game with natural checkmate
#      55 #                   Log += "Found Natural Checkmate game:<br>"
#      56                 else:
#      57 #                   Log += "Not natural checkmate :<br>"
#
# File ~/venv/bin/parse.py:102, in MoveValidation(moves)
#     100         ApprovedMoves = True
#     101         print(moves)
# --> 102         stop()
#     103 #    if "=" in moves:
#     104 #        ApprovedMoves = False
#     106     return ApprovedMoves
#
# NameError: name 'stop' is not defined

# %%
### Update file details in SQL server

print("Connected to MySQL Server: ")
#fs.files_update(Files_id,metric[0],metric[1],file_size,cursor)

print(time.ctime())

# %%
### CLEANUP  the drive

import cleanup as cu
print("Starting Cleanup:")
#storageRemain = cu.Cleanup("",DownloadedCompressedFile,UnCompressedCompletePath)
#print("Output storageRemain: ",storageRemain)
print("Starting Cleanup:")
print(time.ctime())
